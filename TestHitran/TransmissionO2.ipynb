# %% [markdown]
# # Transmission of $O_2$
# - author : Sylvie Dagoret-Campagne
# - date :Jeudi 27 avril 2017

# %%
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
matplotlib.rc_file("templates/matplotlibrc")
import matplotlib.pyplot as plt

# %matplotlib inline

import matplotlib as mpl
# Out:
# /Users/dagoret-campagnesylvie/anaconda/envs/pyastrophys/lib/python2.7/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from hapi import *
# Out:
# HAPI version: 1.1.0.6
# To get the most up-to-date version please check http://hitran.org/hapi

# %%
db_begin('data')
# Out:
# Using data
#
# CO2
#                      Lines parsed: 3831
# H2O
#                      Lines parsed: 64023
# NO2
#                      Lines parsed: 5873
# O2
#                      Lines parsed: 1180
# O3
#                      Lines parsed: 309107

# %% [markdown]
# # Parameters

# %%
WLMIN=200.  # nm
WLMAX=1200. # nm

NUMIN=1e7/WLMAX  # cm-1
NUMAX=1e7/WLMIN  # cm-1

# %%
fetch_by_ids('O2',[36,37,38],NUMIN,NUMAX)
#fetch('O2',7,1,NUMIN,NUMAX)
# Out:
# BEGIN DOWNLOAD: O2
#   65536 bytes written to data/O2.data
#   65536 bytes written to data/O2.data
#   65536 bytes written to data/O2.data
# Header written to data/O2.header
# END DOWNLOAD
#                      Lines parsed: 1180
# PROCESSED

# %%
x,y=getStickXY('O2')

# %%
plt.plot(x,y)

# %%
nu1,coef1 = absorptionCoefficient_Lorentz(SourceTables='O2',OmegaStep=0.0001,Environment={'p': 1.,'T': 296})

# %%
x1,y1=getStickXY('O2')

# %%
nu2,coef2 = absorptionCoefficient_HT(SourceTables='O2',OmegaStep=0.0001,Environment={'p': 1.0,'T': 296})
# Out:
# hapi.py:10349: UserWarning: To get the most up-to-date version please check http://hitran.org/hapi
#   warn('To get the most up-to-date version please check http://hitran.org/hapi')

# %%
x2,y2=getStickXY('O2')

# %%
plt.plot(nu1,coef1,'b-')
plt.plot(nu2,coef2,'r-')

# %%
plt.plot(x1,y1,'b-')
plt.plot(x2,y2,'r-')

# %%
plt.plot(1e7/nu1,coef1,'b-')
plt.plot(1e7/nu2,coef2,'r-')
plt.xlim(675.,775.)
# Out:
# (675.0, 775.0)

# %%
plt.plot(1e7/x1,y1,'b-')
plt.plot(1e7/x2,y2,'r-')
plt.xlim(680.,700.)
# Out:
# (680.0, 700.0)

# %%
plt.plot(1e7/x1,y1,'b-')
plt.plot(1e7/x2,y2,'r-')
plt.xlim(750.,775.)
# Out:
# (750.0, 775.0)
