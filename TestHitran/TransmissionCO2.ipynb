# %% [markdown]
# # Transmission of $CO_2$
# - author : Sylvie Dagoret-Campagne
# - date : May 2nd 2017

# %%
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
matplotlib.rc_file("templates/matplotlibrc")
import matplotlib.pyplot as plt

# %matplotlib inline

import matplotlib as mpl

# %%
from hapi import *

# %%
db_begin('data')
# Out:
# Using data
#
# CO2
#                      Lines parsed: 7869
# H2O
#                      Lines parsed: 110080
# NO2
#                      Lines parsed: 5873
# O
#                      Lines parsed: 80101
# O2
#                      Lines parsed: 1180
# O3
#                      Lines parsed: 16584

# %% [markdown]
# # Parameters

# %%
WLMIN=200.  # nm
WLMAX=1100. # nm

NUMIN=1e7/WLMAX  # cm-1
NUMAX=1e7/WLMIN  # cm-1

# %%
print NUMIN,NUMAX
# Out:
# 9090.90909091 50000.0

# %%
fetch_by_ids('CO2',[7,8,9,10,11,12,13,14,15],NUMIN,NUMAX)
# Out:
# BEGIN DOWNLOAD: CO2
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
#   65536 bytes written to data/CO2.data
# Header written to data/CO2.header
# END DOWNLOAD
#                      Lines parsed: 5728
# PROCESSED

# %%
nu1,coef1 = absorptionCoefficient_Lorentz(Components=((2,1),(2,2),(2,3),(2,4),(2,5),(2,6),(2,7),(2,8),(2,9),),SourceTables='CO2',OmegaStep=0.001,Environment={'p': 0.01,'T': 220})

# %%
plt.plot(nu1,coef1,'b-')

# %%
plt.plot(1e7/nu1,coef1,'b-')
